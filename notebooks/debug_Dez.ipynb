# %%
# use magic command to auto-reload
# %load_ext autoreload
# %autoreload 2

import sys
import os
import numpy as np
import igraph as ig
import json
from dotenv import load_dotenv

sys.path.insert(0, os.path.join(os.getcwd(), '..'))  # parent folder of src
from src.simulation import run_simulation
from src.save import save_simulation_results, show_discussion_from_saved, load_replica
from src.visualization import show_interactive_conversation_tree_with_agent_selection
from dotenv import dotenv_values
import os
import asyncio
import aiohttp
from metrics import calculate_all_metrics, print_summary

# %%
import os
from dotenv import load_dotenv

load_dotenv()

# Load PARAMS
with open("PARAMS.json", "r") as f:
    PARAMS = json.load(f)

# Add HF token from .env
PARAMS["HF_TOKEN"] = os.getenv("HF_TOKEN")

# %%
# Run the simulation
results = await run_simulation(PARAMS)

# Unpack results
List_of_WEIGHTS, List_of_READ_MATRIX, List_of_LIKES, List_of_POSTS, List_of_GRAPHS, List_of_INDIVIDUAL_LIKES = results
# Out:
# 3 0
# T_current: 3
# 4 0
# T_current: 4
# 5 0
# T_current: 5
# 6 0
# T_current: 6
# ---------------------------------------------------------------------------
# ClientResponseError                       Traceback (most recent call last)
# File c:\Users\nel_t\Documents\WORK\PROJECTS\TWON\LSS-KIT\notebooks\..\src\executors\hf.py:120, in execute_prompts_parallel.<locals>.one_call(idx, prompt)
#     119     text = await resp.text()
# --> 120     raise aiohttp.ClientResponseError(
#     121         request_info=resp.request_info,
#     122         history=resp.history,
#     123         status=resp.status,
#     124         message=text,
#     125         headers=resp.headers,
#     126     )
#     127 data = await resp.json()
#
# ClientResponseError: 429, message='{"message":"We\'re experiencing high traffic right now! Please try again soon.","type":"too_many_requests_error","param":"queue","code":"queue_exceeded"}', url='https://router.huggingface.co/v1/chat/completions'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Run the simulation
# ----> 2 results = await run_simulation(PARAMS)
#       4 # Unpack results
#       5 List_of_WEIGHTS, List_of_READ_MATRIX, List_of_LIKES, List_of_POSTS, List_of_GRAPHS, List_of_INDIVIDUAL_LIKES = results
#
# File c:\Users\nel_t\Documents\WORK\PROJECTS\TWON\LSS-KIT\notebooks\..\src\simulation.py:33, in run_simulation(PARAMS)
#      29 print(f"T_current: {G['T_current']}")
#      31 WEIGHTS, TOP_POSTS, READ_MATRIX = _matrix_operations(G, READ_MATRIX, LIKES, PARAMS, WEIGHTS, k=2)
# ---> 33 decision, coords = await evaluate_likes(G, TOP_POSTS, POSTS, PARAMS)
#      34 _update_likes_and_consequences(G, LIKES, INDIVIDUAL_LIKES, decision, coords)
#      36 await generate_posts(G, POSTS, PARAMS)
#
# File c:\Users\nel_t\Documents\WORK\PROJECTS\TWON\LSS-KIT\notebooks\..\src\interfaces.py:39, in evaluate_likes(G, TOP_POSTS, POSTS, PARAMS)
#      37 func = model.evaluate_likes
#      38 if inspect.iscoroutinefunction(func):
# ---> 39     return await func(G, TOP_POSTS, POSTS, PARAMS)
#      40 else:
#      41     return func(G, TOP_POSTS, POSTS, PARAMS)
#
# File c:\Users\nel_t\Documents\WORK\PROJECTS\TWON\LSS-KIT\notebooks\..\src\models\llm\agent.py:133, in evaluate_likes(G, TOP_POSTS, POSTS, PARAMS)
#     130 if not prompts:
#     131     return [], coords3
# --> 133 coords3, texts = await _execute_prompts_with_coords(prompts, coords3, PARAMS, max_tokens=10, temperature=0.5)  # Down from default 128
#     134 decisions = [np.random.rand() < (_extract_number(text) / 9) for text in texts]
#     135 return decisions, coords3
#
# File c:\Users\nel_t\Documents\WORK\PROJECTS\TWON\LSS-KIT\notebooks\..\src\models\llm\utlities.py:141, in _execute_prompts_with_coords(prompts, coords3, PARAMS, max_tokens, batch_size, temperature)
#     139 write_idx = 0
#     140 for start, chunk in _chunks(prompts, batch_size):
# --> 141     texts = await execute_prompts_parallel(
#     142         chunk,
#     143         PARAMS,
#     144         max_tokens=max_tokens,
#     145         temperature=temperature,  # Pass it through
#     146         parse=None
#     147     )
#     148     for text in texts:
#     149         result_coords.append(coords3[write_idx])
#
# File c:\Users\nel_t\Documents\WORK\PROJECTS\TWON\LSS-KIT\notebooks\..\src\executors\hf.py:147, in execute_prompts_parallel(prompts, PARAMS, max_tokens, temperature, parse, timeout, retries, concurrency)
#     144             await asyncio.sleep(0.05 * attempt)
#     146 tasks = [one_call(i, p) for i, p in enumerate(prompts)]
# --> 147 results = await asyncio.gather(*tasks)
#     149 # Restore original order
#     150 results.sort(key=lambda pair: pair[0])
#
# File c:\Users\nel_t\Documents\WORK\PROJECTS\TWON\LSS-KIT\notebooks\..\src\executors\hf.py:141, in execute_prompts_parallel.<locals>.one_call(idx, prompt)
#     139 except Exception as e:
#     140     if attempt > retries:
# --> 141         raise Exception(f"API call failed after {retries} retries for prompt {idx}: {e}")
#     143     # small exponential backoff
#     144     await asyncio.sleep(0.05 * attempt)
#
# Exception: API call failed after 2 retries for prompt 36: 429, message='{"message":"We\'re experiencing high traffic right now! Please try again soon.","type":"too_many_requests_error","param":"queue","code":"queue_exceeded"}', url='https://router.huggingface.co/v1/chat/completions'

# %%
run_path = "runs/Exp_W_post"
results = calculate_all_metrics(run_path)
print_summary(results)


run_path = "runs/Exp_W_personal"
results = calculate_all_metrics(run_path)
print_summary(results)

run_path = "runs/Exp_W_success"
results = calculate_all_metrics(run_path)
print_summary(results)

# %%
def load_params(path="PARAMS.json"):
    with open(path, "r") as f:
        params = json.load(f)

    # normalize legacy keys
    if "warmup_length" not in params and "warmup_length" in params:
        params["warmup_length"] = params.pop("warmup_length")

    return params


# --- load base params ---
PARAMS = load_params("PARAMS.json")

# --- experiment knobs (same as you used before) ---
PARAMS["time_decay_rate"]    = np.log(2) / 2   # half-life = 2 timesteps
PARAMS["W_agent_success"]    = 1
PARAMS["W_personal_weights"] = 0
PARAMS["W_post_success"]     = 0
PARAMS["noise_level"]        = 0.01

# (optional) quick overrides
PARAMS["replicas"]      = 1
PARAMS["num_agents"]    = 30
PARAMS["timesteps"]     = 30
PARAMS["warmup_length"] = 3



# --- secrets from .env (kept out of JSON for safety) ---
ENV = dotenv_values(".env")
for k in ("HF_TOKEN", "API_URL", "MODEL"):
    if k not in ENV or not ENV[k]:
        raise RuntimeError(f"Missing {k} in .env")
    PARAMS[k] = ENV[k]

print(PARAMS)

# %%
# --- run simulation ---
(List_of_WEIGHTS,
    List_of_READ_MATRIX,
    List_of_LIKES,
    List_of_POSTS,
    List_of_GRAPHS,
    List_of_INDIVIDUAL_LIKES) = await run_simulation(PARAMS)

# --- save results (new signature incl. INDIVIDUAL_LIKES) ---
out_root = "runs/Exp_W_success_GEMMA"
save_simulation_results(
    out_root,
    List_of_WEIGHTS, List_of_READ_MATRIX, List_of_LIKES,
    List_of_POSTS, List_of_GRAPHS, List_of_INDIVIDUAL_LIKES,
    PARAMS
)
print(f"Saved run to: {out_root}")
# Out:
# 3 0
# T_current: 3
# 4 0
# T_current: 4
# 5 0
# T_current: 5
# 6 0
# T_current: 6
# 7 0
# T_current: 7
# 8 0
# T_current: 8
# 9 0
# T_current: 9
# 10 0
# T_current: 10
# 11 0
# T_current: 11
# 12 0
# T_current: 12
# 13 0
# T_current: 13
# 14 0
# T_current: 14
# 15 0
# T_current: 15
# 16 0
# T_current: 16
# 17 0
# T_current: 17
# 18 0
# T_current: 18
# 19 0
# T_current: 19
# 20 0
# T_current: 20
# 21 0
# T_current: 21
# 22 0
# T_current: 22
# 23 0
# T_current: 23
# 24 0
# T_current: 24
# 25 0
# T_current: 25
# 26 0
# T_current: 26
# 27 0
# T_current: 27
# 28 0
# T_current: 28
# 29 0
# T_current: 29
# 30 0
# T_current: 30
# 31 0
# T_current: 31
# 32 0
# T_current: 32
# Saved run to: runs/Exp_W_success_GEMMA

# %%
# --- run simulation ---
(List_of_WEIGHTS,
    List_of_READ_MATRIX,
    List_of_LIKES,
    List_of_POSTS,
    List_of_GRAPHS,
    List_of_INDIVIDUAL_LIKES) = await run_simulation(PARAMS)

# --- save results (new signature incl. INDIVIDUAL_LIKES) ---
out_root = "runs/Exp_W_success_1"
save_simulation_results(
    out_root,
    List_of_WEIGHTS, List_of_READ_MATRIX, List_of_LIKES,
    List_of_POSTS, List_of_GRAPHS, List_of_INDIVIDUAL_LIKES,
    PARAMS
)
print(f"Saved run to: {out_root}")

# %%
# --- run simulation ---
(List_of_WEIGHTS,
    List_of_READ_MATRIX,
    List_of_LIKES,
    List_of_POSTS,
    List_of_GRAPHS,
    List_of_INDIVIDUAL_LIKES) = await run_simulation(PARAMS)

# --- save results (new signature incl. INDIVIDUAL_LIKES) ---
out_root = "runs/Exp_W_success_2"
save_simulation_results(
    out_root,
    List_of_WEIGHTS, List_of_READ_MATRIX, List_of_LIKES,
    List_of_POSTS, List_of_GRAPHS, List_of_INDIVIDUAL_LIKES,
    PARAMS
)
print(f"Saved run to: {out_root}")

# %%
# --- run simulation ---
(List_of_WEIGHTS,
    List_of_READ_MATRIX,
    List_of_LIKES,
    List_of_POSTS,
    List_of_GRAPHS,
    List_of_INDIVIDUAL_LIKES) = await run_simulation(PARAMS)

# --- save results (new signature incl. INDIVIDUAL_LIKES) ---
out_root = "runs/Exp_W_success_3"
save_simulation_results(
    out_root,
    List_of_WEIGHTS, List_of_READ_MATRIX, List_of_LIKES,
    List_of_POSTS, List_of_GRAPHS, List_of_INDIVIDUAL_LIKES,
    PARAMS
)
print(f"Saved run to: {out_root}")

# %%
# --- run simulation ---
(List_of_WEIGHTS,
    List_of_READ_MATRIX,
    List_of_LIKES,
    List_of_POSTS,
    List_of_GRAPHS,
    List_of_INDIVIDUAL_LIKES) = await run_simulation(PARAMS)

# --- save results (new signature incl. INDIVIDUAL_LIKES) ---
out_root = "runs/Exp_W_success_4"
save_simulation_results(
    out_root,
    List_of_WEIGHTS, List_of_READ_MATRIX, List_of_LIKES,
    List_of_POSTS, List_of_GRAPHS, List_of_INDIVIDUAL_LIKES,
    PARAMS
)
print(f"Saved run to: {out_root}")

# %%
def load_params(path="PARAMS.json"):
    with open(path, "r") as f:
        params = json.load(f)

    # normalize legacy keys
    if "warmup_length" not in params and "warmup_length" in params:
        params["warmup_length"] = params.pop("warmup_length")

    return params


# --- load base params ---
PARAMS = load_params("PARAMS.json")

# --- experiment knobs (same as you used before) ---
PARAMS["time_decay_rate"]    = np.log(2) / 2   # half-life = 2 timesteps
PARAMS["W_agent_success"]    = 0
PARAMS["W_personal_weights"] = 1
PARAMS["W_post_success"]     = 0
PARAMS["noise_level"]        = 0.01

# (optional) quick overrides
PARAMS["replicas"] = 5

PARAMS["num_agents"]   = 30
PARAMS["timesteps"]    = 30
PARAMS["warmup_length"] = 3



# --- secrets from .env (kept out of JSON for safety) ---
ENV = dotenv_values(".env")
for k in ("HF_TOKEN", "API_URL", "MODEL"):
    if k not in ENV or not ENV[k]:
        raise RuntimeError(f"Missing {k} in .env")
    PARAMS[k] = ENV[k]


# --- run simulation ---
(List_of_WEIGHTS1,
    List_of_READ_MATRIX1,
    List_of_LIKES1,
    List_of_POSTS1,
    List_of_GRAPHS1,
    List_of_INDIVIDUAL_LIKES1) = await run_simulation(PARAMS)

# --- save results (new signature incl. INDIVIDUAL_LIKES) ---
out_root = "runs/Exp_W_personal"
save_simulation_results(
    out_root,
    List_of_WEIGHTS1, List_of_READ_MATRIX1, List_of_LIKES1,
    List_of_POSTS1, List_of_GRAPHS1, List_of_INDIVIDUAL_LIKES1,
    PARAMS
)
print(f"Saved run to: {out_root}")

# %%
def load_params(path="PARAMS.json"):
    with open(path, "r") as f:
        params = json.load(f)

    # normalize legacy keys
    if "warmup_length" not in params and "warmup_length" in params:
        params["warmup_length"] = params.pop("warmup_length")

    return params


# --- load base params ---
PARAMS = load_params("PARAMS.json")

# --- experiment knobs (same as you used before) ---
PARAMS["time_decay_rate"]    = np.log(2) / 2   # half-life = 2 timesteps
PARAMS["W_agent_success"]    = 0
PARAMS["W_personal_weights"] = 0
PARAMS["W_post_success"]     = 1
PARAMS["noise_level"]        = 0.01

# (optional) quick overrides
PARAMS["replicas"] = 5

PARAMS["num_agents"]   = 30
PARAMS["timesteps"]    = 30
PARAMS["warmup_length"] = 3



# --- secrets from .env (kept out of JSON for safety) ---
ENV = dotenv_values(".env")
for k in ("HF_TOKEN", "API_URL", "MODEL"):
    if k not in ENV or not ENV[k]:
        raise RuntimeError(f"Missing {k} in .env")
    PARAMS[k] = ENV[k]


# --- run simulation ---
(List_of_WEIGHTS2,
    List_of_READ_MATRIX2,
    List_of_LIKES2,
    List_of_POSTS2,
    List_of_GRAPHS2,
    List_of_INDIVIDUAL_LIKES2) = await run_simulation(PARAMS)

# --- save results (new signature incl. INDIVIDUAL_LIKES) ---
out_root = "runs/Exp_W_post"
save_simulation_results(
    out_root,
    List_of_WEIGHTS2, List_of_READ_MATRIX2, List_of_LIKES2,
    List_of_POSTS2, List_of_GRAPHS2, List_of_INDIVIDUAL_LIKES2,
    PARAMS
)
print(f"Saved run to: {out_root}")

# %%
# Load a specific replica
replica_dir = "runs/r000"  # Replace with your actual path
replica_data = load_replica(replica_dir)

# Extract the individual likes data
individual_likes_data = replica_data["INDIVIDUAL_LIKES"]

# Check its structure
print("Shape:", individual_likes_data.shape)
print("Type:", type(individual_likes_data))

# %%
print("List shape:", List_of_INDIVIDUAL_LIKES[0].shape)
print("Loaded shape:", individual_likes_data.shape)
print("Are they equal?", np.array_equal(List_of_INDIVIDUAL_LIKES[0], individual_likes_data))

# %%
fig = show_interactive_conversation_tree_with_agent_selection("runs/r000")

# %%
print(List_of_POSTS[0][3][0])
